# %% [markdown]
# # S14 Group 14 - Hotel Booking Demand
# Group Members
# * Annika Capada
# * Lauren Garcia
# * Angel Lou Yabut

# %% [markdown]
# # Data Set Description
#
# In this section of the notebook, you must fulfill the following:
# * State a brief description of the dataset.
# * Provide a description of the collection process executed to build the dataset. Discuss the implications of the data collection method on the generated conclusions and insights. Note that you may need to look at relevant sources related to the dataset to be able to provide the necessary information for this part of the project.
# * Describe the structure of the dataset file. In the dataset file, what does each row and column represent? How many observations are there in the dataset? How many variables are there in the dataset? If the dataset is composed of different files that you will combine
# in the succeeding steps, describe the structure and the contents of each file.
# * Discuss the variables in each dataset file. What does each variable represent? In this section, all variables, even those which are not used for the study, should be described to the reader. The purpose of each variable in the dataset should be clear to the reader of the notebook without having to go through an external link.

# %% [markdown]
# ## Brief Description
# The dataset that we will be using is the [Hotel Booking Demand](https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand) from Kaggle. According to the author of the Kaggle dataset, Jesse Mostipak, she states "This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things."

# %% [markdown]
# ## Collection Process
# The dataset was originally from the article [Hotel Booking Demand Datasets](https://www.sciencedirect.com/science/article/pii/S2352340918315191), , written by Nuno Antonio, Ana Almeida, and Luis Nunes for Data in Brief, Volume 22, February 2019. This dataset investigates the hotel booking information of city and resort hotels from Portugal, more specifically from the cities of Algarve and Lisbon.The authors state they directly got the data from the hotels Property Management System (PMS) databases servers by executing a TSQL query. However, because in the hotel industry, consumers frequently modify the details of their bookings. It is comprehensible that the distribution of some variables may differ between non-canceled and canceled bookings, hence, it is necessary to consider this difference in distribution while using these datasets.

# %% [markdown]
# ## Structure
# In the dataset, each row represents an observation concerning the booking information of one of the two types of hotels: city hotels and resort hotels. Each column represents the different variables and correspoding data related to each. Wherein, there is a total of 119390 observations with 32 variables each.

# %% [markdown]
# ## Variables
# If you view the `.csv` file in Excel, you can see that our dataset contains many **observations** (rows) across 32 **variables** (columns). The following are the descriptions of each variable in the dataset.
#
# - **`hotel`**: category of the hotel, either City or Resort Hotel
# - **`is_canceled`**: value indicating if the booking was canceled (1) or not (0)
# - **`lead_time`**: number of days that elapsed between the entering date of the booking into the PMS and the arrival date
# - **`arrival_date_year`**: year of arrival date
# - **`arrival_date_month`**: month of arrival date
# - **`arrival_date_week_number`**: week number of year for arrival date
# - **`arrival_date_day_of_month`**: day of arrival date
# - **`stays_in_weekend_nights`**: number of weekend nights the guest stayed or booked to stay at the hotel
# - **`stays_in_week_nights`**: number of week nights the guest stayed or booked to stay at the hotel
# - **`adults`**: number of adults
# - **`children`**: number of children
# - **`babies`**: number of babies
# - **`meal`**: type of meal booked, presented in standard hospitality meal packages
# - **`country`**: country of origin
# - **`market_segment`**: market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - **`distribution_channel`**: booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - **`is_repeated_guest`**: value indicating if the booking name was from a repeated guest (1) or not (0)
# - **`previous_cancellations`**: number of previous bookings that were cancelled by the customer prior to the current booking
# - **`previous_bookings_not_canceled`**: number of previous bookings not cancelled by the customer prior to the current booking
# - **`reserved_room_type`**: code of room type reserved. Code is presented instead of designation for anonymity reasons.
# - **`assigned_room_type`**: code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due
# - **`booking_changes`**: number of changes/amendments made to the booking from the moment the booking was entered on the PMS
# - **`deposit_type`**: Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories: No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
# - **`agent`**: ID of the travel agency that made the booking
# - **`company`**: ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# - **`days_in_waiting_list`**: number of days the booking was in the waiting list before it was confirmed to the customer
# - **`customer_type`**: type of booking, assuming one of four categories: Contract - when the booking has an allotment or other type of contract associated to it; Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when the booking is transient, but is associated to at least other transient booking
# - **`adr`**: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
# - **`required_car_parking_spaces`**: number of car parking spaces required by the customer
# - **`total_of_special_requests`**: Number of special requests made by the customer (e.g. twin bed or high floor)
# - **`reservation_status`**: Reservation last status, assuming one of three categories: Canceled – booking was canceled by the customer; Check-Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why
# - **`reservation_status_date`**: Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# # Data Cleaning
#
# For each used variable, check for the following and, if needed, perform data cleaning:
# * There are multiple representations of the same categorical value.
# * The datatype of the variable is incorrect.
# * Some values are set to default values of the variable.
# * There are missing data.
# * There are duplicate data.
# * The formatting of the values is inconsistent.
#
# Note: No need to clean all variables. Clean only the variables utilized in the study.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
hbd_df = pd.read_csv("hotel_bookings.csv")

# %%
hbd_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hbd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## Checking for Duplicates
# The first thing we did is to check if the dataset had any duplicates using the duplicated() function

# %%
hbd_df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# As we can see, there's a total of 31994 duplicate rows. We dropped these rows to remove the duplicates.

# %%
hbd_df.loc[hbd_df.duplicated(),:]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
hbd_df.drop_duplicates(keep='first', inplace=True)

# %%
hbd_df.duplicated().sum()
# Out:
# 0

# %%
hbd_df.shape
# Out:
# (87396, 32)

# %% [markdown]
# After removing the duplicates, the number of rows has reduced to 87396.

# %% [markdown]
# ## Checking for NaNs
# We will now handle missing data in our dataset. We check each column to see if it contains a `NaN` / `null` value.

# %%
hbd_df.isnull().any()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                           True
# babies                            False
# meal                              False
# country                            True
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# ...

# %% [markdown]
# Now we list all of the columns with NaN/null values.

# %%
nan_variables = hbd_df.columns[hbd_df.isnull().any()].tolist()
print(nan_variables)
# Out:
# ['children', 'country', 'agent', 'company']

# %% [markdown]
# We notice that there's 4 columns that contain null values. Let's see how many null values there are exactly in each column to see whether such rows can simply be deleted or if the whole column can be removed.

# %%
hbd_df[nan_variables].isnull().sum() #filters columns that have nan
# Out:
# children        4
# country       452
# agent       12193
# company     82137
# dtype: int64

# %% [markdown]
# We will see how much the missing values in **nan_variables** make up for the number of total values in the observation.

# %%
#percentage of data representing missing agent 
missing_children = 100*hbd_df["children"].isnull().sum()/hbd_df.shape[0]
missing_country = 100*hbd_df["country"].isnull().sum()/hbd_df.shape[0]
missing_agent = 100*hbd_df["agent"].isnull().sum()/hbd_df.shape[0]
missing_company = 100*hbd_df['company'].isnull().sum()/hbd_df.shape[0]

print("Percentage of missing children: " + str(missing_children.round(2)))
print("Percentage of missing country: " + str(missing_country.round(2)))
print("Percentage of missing agents: " + str(missing_agent.round(2)))
print("Percentage of missing company: " + str(missing_company.round(2)))
# Out:
# Percentage of missing children: 0.0
# Percentage of missing country: 0.52
# Percentage of missing agents: 13.95
# Percentage of missing company: 93.98

# %% [markdown]
# For **`children`**, we can remove the rows containing missing values under the column because only 4 contain missing values which does not remove a significant amount of data. For **`country`**, we can remove the rows with missing values as well since the amount of missing values only makes up for 0.52 percent of the data. For **`agents`** and **`company`**, we will remove these columns because we find the **`agents`** column irrelevant to our study and **`company`** has too many missing values. Deleting missing rows under **`company`** would make the data unusable.

# %%
hbd_df.drop("agent", axis=1, inplace=True)
hbd_df.drop("company", axis=1, inplace=True)

# %%
#delete empty values in the specific columns "children" and "country"
hbd_df.dropna(subset=["children","country"],inplace=True)

# %%
hbd_df.shape
# Out:
# (86940, 30)

# %% [markdown]
# After removing rows with null values and dropping columns that were deemed irrelevant and unusable to the study, the final shape has been modified to 86940 rows and 30 columns.

# %% [markdown]
# # Exploratory Data Analysis
#
# Perform exploratory data analysis comprehensively to gain a good understanding of your dataset. This step should help in formulating the research question of the project.
# In this section of the notebook, you must fulfill the following:
# * Identify three (3) exploratory data analysis questions. Properly state the questions in the
# notebook.
# * Answer the EDA questions using both:
#     * Numerical Summaries – measures of central tendency, measures of dispersion, and correlation
#
#     * Visualization – Appropriate visualization should be used. Each visualization should be accompanied by a brief explanation.
#
# To emphasize, both numerical summary and visualization should be presented for each question. The whole process should be supported with verbose textual descriptions of your procedures and findings.

# %% [markdown]
# ## 1. How many bookings are canceled and not canceled?
#
# To answer this question, the variables of interest are:
# - **`is_canceled`**: value indicating if the booking was canceled (1) or not (0)

# %% [markdown]
# To determine the number of canceled and not canceled bookings, we count the values of 0 and 1 under the **`is_canceled`** column using the .value_counts() function. A bar plot is used to visualize these values as well as to compare the difference between the boolean values of **`is_canceled`**.

# %%
canceled_count = hbd_df['is_canceled'].value_counts()
canceled_count
# Out:
# 0    62953
# 1    23987
# Name: is_canceled, dtype: int64

# %%
canceled_count.plot.barh(figsize=(10,5)).invert_yaxis() #figsize configures the size of the chart
plt.ylabel('Is Canceled')
plt.xlabel('Count')
plt.title('Number of Cancelations and Non-Cancelations')
# Out:
# Text(0.5, 1.0, 'Number of Cancelations and Non-Cancelations')

# %% [markdown]
# In the bar graph, we can see that the the total count of guests who did not cancel their reservation is more than the number of guests that did. Wherein, there are only 23987 cancelations compared to the 62953 that pushed through.

# %% [markdown]
# ## 2. Which month has the most cancelations?
#
# To answer this question, the variables of interest are:
# - **`is_canceled`**: value indicating if the booking was canceled (1) or not (0)
# - **`arrival_date_month`**: month of arrival date
#
# To answer this question, we filter the dataframe so that the **`is_canceled`** is equal to 1 and that the data is grouped by **`arrival_date_month`**. A count plot is used to visualize these values as well.

# %%
months_df = hbd_df[hbd_df["is_canceled"] == 1]
months_df.value_counts('arrival_date_month')
# Out:
# arrival_date_month
# August       3618
# July         3192
# May          2442
# April        2404
# June         2353
# March        1829
# October      1637
# September    1636
# February     1414
# December     1373
# November     1052
# January      1037
# dtype: int64

# %%
plt.figure(figsize = (10, 5))

#crest
sns.countplot(x = 'arrival_date_month', data = hbd_df, dodge = 'is_canceled', order=["January","February","March","April","May","June",
                                                                              "July","August","September","October","November","December"],palette = 'Set1_r')
plt.title('Monthly Cancelations', )
plt.xlabel('Months')
plt.ylabel('Number of canceled bookings')

plt.tight_layout()

# %% [markdown]
# In the bar graph and the value counts, we see that the month of August has the most cancelations.

# %% [markdown]
# From this point forward, we will continue to focus only on data where guests did not cancel their booking reservations. Therefore, we create a dataframe that filters out this data called **`confirmed_bookings`**.

# %%
confirmed_bookings = hbd_df[hbd_df["is_canceled"] == 0]

# %% [markdown]
# ## 3. What is the month with the most hotel bookings per hotel type?
#
# To answer this question, the variables of interest are:
# - **`arrival_date_month`**: month of arrival date
# - **`hotel`**: category of the hotel, either City or Resort Hotel

# %% [markdown]
# To indentify the total number of reservations made per month, we count the number of bookings made depending on the month under the **`arrival_date_month`** column using the .value_counts() function. For the comparison of the number of bookings made per month on each hotel type, a countplot is used.

# %%
guest_count = confirmed_bookings['arrival_date_month'].value_counts()
guest_count
# Out:
# August       7614
# July         6832
# May          5901
# March        5630
# April        5467
# June         5400
# October      5246
# September    5023
# February     4629
# November     3901
# December     3709
# January      3601
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# Here we see the number of guests for each month and we see that August is the highest when considering city resort hotels combined. Let's separate the two types of hotels and see if anything changes.

# %%
city_hotel = hbd_df[(hbd_df["is_canceled"] == 0) & (hbd_df["hotel"] == 'City Hotel')]
city_guest = city_hotel['arrival_date_month'].value_counts()
city_guest
# Out:
# August       4481
# July         3846
# May          3667
# March        3491
# June         3484
# April        3330
# September    3173
# October      3081
# February     2630
# November     2194
# December     2034
# January      1966
# Name: arrival_date_month, dtype: int64

# %%
resort_hotel = hbd_df[(hbd_df["is_canceled"] == 0) & (hbd_df["hotel"] == 'Resort Hotel')]
resort_guest = resort_hotel['arrival_date_month'].value_counts()
resort_guest
# Out:
# August       3133
# July         2986
# May          2234
# October      2165
# March        2139
# April        2137
# February     1999
# June         1916
# September    1850
# November     1707
# December     1675
# January      1635
# Name: arrival_date_month, dtype: int64

# %%
plt.figure(figsize = (10, 5))

#crest
sns.countplot(x = 'arrival_date_month', hue = 'hotel', data = confirmed_bookings, order=["January","February","March","April","May","June",
                                                                              "July","August","September","October","November","December"],palette = 'Set1_r')
plt.title('Monthly arrivals', )
plt.xlabel('Months')
plt.ylabel('Number of bookings')

plt.tight_layout()

# %% [markdown]
# We see that August is the busiest month for both Resort and City hotels in terms of hotel booking reservations. Following as the second and third busiest months are the months of July and May respectively. Then the fourth busiest month and onwards are different for both hotels with March being the fourth busiest for city hotels and October for resort hotels.
#
# We also notice that city hotels generally have more booking reservations over resort hotels. This could be because city hotels tend to be cheaper, more accessible, and more suitable for individuals or small groups of guests.

# %% [markdown]
# ## 4. What is the Average Number of Lead Time Per Month?
#
# To answer this question, the variables of interest are:
# - **`arrival_date_month`**: month of arrival date
# - **`lead_time`**: number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# To answer this question, we aggregate the data to collect the mean, median, and standard deviation of the lead time and group the data by arrival date month. Then, we visualize the distribution through a boxplot.

# %%
confirmed_bookings.groupby("arrival_date_month").agg({"lead_time": ["mean", "median", "std"]})
# Out:
#                      lead_time
#                           mean median         std
# arrival_date_month
# April                67.514908   56.0   65.572833
# August               90.545443   67.0   86.571385
# December             45.172823   20.0   59.661374
# February             28.371571   12.0   44.346194
# January              25.866981    7.0   43.958406
# July                103.232143   92.0   88.101881
# June                 96.776852   74.0   92.377572
# March                47.355773   30.0   55.168471
# May                  83.531605   64.0   84.804984
# November             40.740836   24.0   52.335483
# October              74.951582   34.0   95.995440
# September            88.316743   46.0  101.484163

# %% [markdown]
# We can see that July has the highest mean with 103.23 and the highest median at 92.0. On the other hand, January has both the lowest mean and median with 25.87 and 7.0 respectively. For the case of the standard deviation, September has the highest with 88.32 while February has the lowest with 44.35.

# %%
confirmed_bookings.boxplot("lead_time", by="arrival_date_month",figsize=(15,10))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# In this boxplot we can observe that July has highest median. Additionally, the lowest lower whisker is 0 which applies to all months while the month with the highest upper whisker is August. This implies that in all months there are guests that are able to arrive at the same day as they booked the hotel. On the hand, during August, it suggests that booking is more difficult for they need to wait a longer time before they can stay at the hotel.

# %% [markdown]
# ## 5. Could there be a relationship between hotel type and lead time?
# To answer this question, the variables of interest are:
# - **`hotel`**: category of the hotel, either City or Resort Hotel
# - **`lead_time`**: number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# To answer this question, we aggregate the data to collect the mean, median, and standard deviation of the lead time and group the data by hotel type. Then, we visualize the distribution through a boxplot.

# %%
summary_stat = confirmed_bookings.groupby("hotel").agg({"lead_time": ["mean", "median", "std", len]})
summary_stat
# Out:
#               lead_time
#                    mean median        std    len
# hotel
# City Hotel    67.391471   40.0  75.543155  37377
# Resort Hotel  74.867141   35.0  89.783609  25576

# %%
confirmed_bookings.groupby("hotel").boxplot(column="lead_time")
plt.show()

# %% [markdown]
# It appears that guests who book at resort hotels tend to have a larger lead time, meaning that they book with more time in advance, compared to city hotels. However, this data alone does not show that the difference is statistically significant.

# %% [markdown]
# ## 6. How many reservations are made by repeated guests per hotel type?
#
# To answer this question, the variables of interest are:
# - **`is_repeated_guest`**: month of arrival date
# - **`hotel`**: category of the hotel, either City or Resort Hotel

# %% [markdown]
# To solve for this, we count the values of 0 and 1 under the **'is_repeated_guest column'**. We visualize these values through a countplot to see how large the difference between the boolean values of **`is_repeated_guest`**.

# %%
repeated_count = confirmed_bookings['is_repeated_guest'].value_counts()
repeated_count
# Out:
# 0    59803
# 1     3150
# Name: is_repeated_guest, dtype: int64

# %%
plt.figure(figsize = (10, 5))

#crest
sns.countplot(x = 'is_repeated_guest', data = hbd_df, hue = 'hotel', palette = 'Set1_r')
plt.title('Is Repeated Guest per hotel')
plt.xlabel('Repeated Guest Boolean')
plt.ylabel('Number of bookings')

plt.tight_layout()

# %% [markdown]
# We notice on the countplot is that most of the guests in the dataset are not repeated guests to the hotels they reserved at whether it be a resort or city hotel. This can mean many things such as people would rather explore different hotels and not repeat, people did not enjoy their experience at the hotel they stayed at, etc.

# %% [markdown]
# ## 7. What are the top 10 countries that hotel guests originate from?
#
# To answer this question, the variables of interest are:
# - **`country`**: country of origin
#
# To answer this question, we use the .value_counts() function to count the number of times a country appears in the dataset. We use a barpolot to visualize the difference of these values.

# %%
country_count = confirmed_bookings['country'].value_counts()
country_count[:10]
# Out:
# PRT    17662
# GBR     8448
# FRA     7104
# ESP     5390
# DEU     4334
# IRL     2348
# ITA     1991
# BEL     1670
# NLD     1561
# USA     1416
# Name: country, dtype: int64

# %%
country_df = confirmed_bookings['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]
plt.figure(figsize=(20, 8))
sns.barplot(x=country_df['country'], y=country_df['count of guests'])
plt.xlabel("Country")
plt.ylabel("Number of guests")
plt.title("Number of guests from top 10 countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from top 10 countries')

# %% [markdown]
# Based on the barplot, we notice that the top 10 countries of origin of hotel guests are the following:
#
# 1. PRT - Portugal
# 2. GBR - United kingdom
# 3. FRA - France
# 4. ESP - Spain
# 5. DEU - Germany
# 6. IRL - Ireland
# 7. ITA - Italy
# 8. BEL - Belgium
# 9. NLD - Netherlands
# 10. USA - United States of America
#
# We can observe in particular that many of the guests come from different countries of Europe. This is understandable as the hotels referred to in the dataset are located in Portugal. With that, we can also observe that Portugal has a lot of citizens travelling domestically.

# %% [markdown]
# ## 8. What is the month with the most hotel bookings with children?
#
# To answer this question, the variables of interest are:
# - **`children`**: number of children included in the booking reservation
# - **`babies`**: number of babies included in the booking reservation
# - **`hotel`**: category of the hotel, either City or Resort Hotel
#
#
# To answer this question, we first create a column that combines the **`children`** and **`babies`** variables so we get the total number of children which includes infants. This column will be named **`total_kids`** under the use the **`confirmed_bookings`** dataframe. Then, we use the value_counts() function to count the number of times a hotel booking with children appears in the dataset. We use a barpolot to visualize the difference of these values.

# %%
confirmed_bookings['total_kids'] = confirmed_bookings['children'] + confirmed_bookings['babies']
# Out:
# <ipython-input-34-fa54df993a10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confirmed_bookings['total_kids'] = confirmed_bookings['children'] + confirmed_bookings['babies']

# %%
with_kids = confirmed_bookings[(confirmed_bookings["total_kids"] > 0)]
kid_guest = with_kids['arrival_date_month'].value_counts()
kid_guest
# Out:
# August       1369
# July         1136
# April         479
# June          434
# February      426
# December      372
# May           364
# March         348
# October       347
# September     292
# January       239
# November      165
# Name: arrival_date_month, dtype: int64

# %%
plt.figure(figsize = (10, 5))

#crest
sns.countplot(x = 'arrival_date_month', data = with_kids, hue = 'hotel', order=["January","February","March","April","May","June",
                                                                              "July","August","September","October","November","December"], palette = 'Set1_r')
plt.title('Monthly arrivals', )
plt.xlabel('Months')
plt.ylabel('Reservations with children')

plt.tight_layout()

# %% [markdown]
# Based on the count plot, majority of the guests with children for both Resort and City Hotel book their hotel reservations on the month of August followed by July as the second highest. This is possibly because those months are the summer break for children.

# %% [markdown]
# ## 9. What is the Average Daily Rate per hotel type
#
# To answer this question, the variables of interest are:
# - **`adr`**: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
# - **`hotel`**: category of the hotel, either City or Resort Hotel
#
# To answer this question, we aggregate the data to collect the mean, median, and standard deviation of the average daily rate (ADR) and group the data by hotel type. Then, we visualize the distribution through a boxplot.

# %%
adr_children = confirmed_bookings.groupby("hotel").agg({"adr": ["mean","median", "std"]})
adr_children.sort_values(("adr", "median"), ascending=False)
# Out:
#                      adr
#                     mean median        std
# hotel
# City Hotel    108.286095  102.0  42.608551
# Resort Hotel   93.496544   75.0  60.818798

# %% [markdown]
# We can see that City Hotel has the highest mean with 108.29 and the highest median at 102.0. On the other hand, Resort Hotel has both the lowest mean and median with 93.49 and 75.0 respectively. Whereas, for standard deviation, Resort Hotel was higher garnering the value of 60.82 while City Hotel was lower with the value of 31.29. Therefore, because City Hotels have a higher mean, this could imply that guests that book at City Hotels spend a higher ADR due to longer length of stay or higher cost of transactions.

# %%
confirmed_bookings.boxplot("adr", by="hotel", figsize=(15,10))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Based on the box plot, we can observe that City Hotel has a higher median compared to Resort Hotel. Additionally, the highest upper whisker and the lowest lower whisker is Resort Hotel.

# %% [markdown]
# ## 10. Is there a relationship between the number of stays in weekend nights and week nights with the Average Daily Rate?
#
# To answer this question, the variables of interest are:
# - **`stays_in_weekend_nights`**: number of weekend nights the guest stayed or booked to stay at the hotel
# - **`stays_in_week_nights`**: number of week nights the guest stayed or booked to stay at the hotel
# - **`adr`**: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# To answer this question, we get the correlation between all three values using the .corr() function and we visualize these relationships using scatter plots.

# %%
adr_stays = confirmed_bookings[['adr', 'stays_in_weekend_nights', 'stays_in_week_nights']]
adr_stays.corr()
# Out:
#                               adr  stays_in_weekend_nights  \
# adr                      1.000000                 0.033236
# stays_in_weekend_nights  0.033236                 1.000000
# stays_in_week_nights     0.044536                 0.539000
#
#                          stays_in_week_nights
# adr                                  0.044536
# stays_in_weekend_nights              0.539000
# stays_in_week_nights                 1.000000

# %%
adr_stays.plot.scatter(x='stays_in_weekend_nights', y='adr', alpha=0.4)
plt.title('Relationship of Stays in Weekend Nights and ADR')
# Out:
# Text(0.5, 1.0, 'Relationship of Stays in Weekend Nights and ADR')

# %%
adr_stays.plot.scatter(x='stays_in_week_nights', y='adr', alpha=0.4)
plt.title('Relationship of Stays in Weekend Nights and ADR')
# Out:
# Text(0.5, 1.0, 'Relationship of Stays in Weekend Nights and ADR')

# %% [markdown]
# The graphs look negatively correlated but the values are positive. The correlation values are very small so the relationship between the variables may be very weak.

# %% [markdown]
# # Research Question
# Come up with one (1) research question to answer using the dataset. Here are some requirements:
# * The research question should arise from the exploratory data analysis. There should be
# an explanation regarding the connection of the research question to the answers obtained
# from performing exploratory data analysis.
# * The research question should be within the scope of the dataset.
# * The research question should be answerable by either performing data mining techniques or any domain-specific data modelling technique (i.e., techniques in modelling text, time-series, graph, or image data) taught in class.
# * Make sure to indicate the importance and significance of the research question.

# %% [markdown]
# ## Is there any pattern that is common with the booking date and arrival date of resort and city hotels?
#
# This question arose from exploring the lead time of the bookings and how it varied through different months. The dataset does not contain the initial dates of booking so in the next phase, we would like to create that variable and explore how the booking date may have some sort of a relationship with the arrival date.
#
# This research question was chosen so that if any pattern or relationship is identified between the booking date and arrival date, then hotel guests can get a better idea of when to book their hotel stays and secure a hotel room. This question would also help hotel workers understand when more guests would arrive. This would allow them to prepare in advance and provide quality customer experience especially during busy times. Additionally, enforce strategies to maximize efficiency and profit depending on the month.
#
# To answer this question, we plan on using the time-series data modelling technique. Through this technique, we would like to observe how the booking date and arrival date varies through months and years.

# %%
hbd_df.to_csv('hbd_clean.csv', index=True)
